# %%
import pandas as pd
import random 
import numpy as np

# %%
random_sample = [random.choice([1, 2, 3, 4, 5, 6, 7, 8]) for i in range(0, 50000)]

# %%
df = pd.DataFrame(data={'sample': random_sample})

# %%
df.describe()
# Out:
#              sample
# count  50000.000000
# mean       4.489500
# std        2.288885
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        6.000000
# max        8.000000

# %%
df.to_csv("D:\R program\IT box\Dataset\\test.csv")

# %%
df.plot.box()
# Out:
# <AxesSubplot: >

# %%
df.value_counts()
# Out:
# sample
# 7         913
# 5         906
# 6         899
# 4         896
# 1         886
# 2         885
# 0         882
# 3         879
# 8         854
# dtype: int64

# %%
df.replace(0, np.nan, inplace=True)

# %%
df.value_counts(dropna=False)
# Out:
# sample
# 7.0       913
# 5.0       906
# 6.0       899
# 4.0       896
# 1.0       886
# 2.0       885
# NaN       882
# 3.0       879
# 8.0       854
# dtype: int64

# %%
df.plot.box()
# Out:
# <AxesSubplot: >

# %%
df.skew()
# Out:
# sample   -0.008969
# dtype: float64

# %%
print(df.mean())
print(df.median())
# Out:
# sample    4.499017
# dtype: float64
# sample    5.0
# dtype: float64

# %%
df.replace(np.nan, df.mean(), inplace=True)

# %%
df.plot.box()
# Out:
# <AxesSubplot: >

# %%
df.skew()
# Out:
# sample   -0.009509
# dtype: float64

# %%
print(df.mean())
print(df.median())
# Out:
# sample    4.499017
# dtype: float64
# sample    4.499017
# dtype: float64

# %% [markdown]
# # Normal Distribution

# %%
data = [1, 2, 3, 3, 4, 5, np.nan, np.nan]

# %%
dataframe = pd.DataFrame(data=data, columns=["number"])

# %%
dataframe
# Out:
#    number
# 0     1.0
# 1     2.0
# 2     3.0
# 3     3.0
# 4     4.0
# 5     5.0
# 6     NaN
# 7     NaN

# %%
dataframe.plot.box()
# Out:
# <AxesSubplot: >

# %%
dataframe.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
dataframe.plot(kind='kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
dataframe.skew()
# Out:
# number    0.0
# dtype: float64

# %%
data2 = [1, 2, 3, 3, 4, 5, 2, 5, 7, 8, np.nan, np.nan, np.nan]

# %%
dataframe2 = pd.DataFrame(data=data2, columns=['number'])

# %%
dataframe2.plot.box()
# Out:
# <AxesSubplot: >

# %%
dataframe2.plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
dataframe2.skew()
# Out:
# number    0.576947
# dtype: float64

# %%
dataframe2.replace(np.NaN, dataframe2.mean(), inplace=True)

# %%
dataframe2
# Out:
#     number
# 0      1.0
# 1      2.0
# 2      3.0
# 3      3.0
# 4      4.0
# 5      5.0
# 6      2.0
# 7      5.0
# 8      7.0
# 9      8.0
# 10     4.0
# 11     4.0
# 12     4.0

# %%
dataframe2.plot.box()
# Out:
# <AxesSubplot: >

# %%
dataframe2.plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
data3 = [1, 2, 3, 3, 4, 5, 2, 5, 7, 8, np.nan, np.nan, np.nan]

# %%
dataframe3 = pd.DataFrame(data=data3, columns=['number'])

# %%
dataframe3.replace(np.nan, dataframe3.median())
# Out:
#     number
# 0      1.0
# 1      2.0
# 2      3.0
# 3      3.0
# 4      4.0
# 5      5.0
# 6      2.0
# 7      5.0
# 8      7.0
# 9      8.0
# 10     3.5
# 11     3.5
# 12     3.5

# %%
dataframe3.plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
dataframe3.plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
test = [2, 5, 5, 6, 6, 7, 7, 7, 8, 8, 8, 8, 9, 10, 10]

# %%
data_test = pd.DataFrame(data=test, columns=['number'])

# %%
data_test.plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
data_test.describe()
# Out:
#           number
# count  15.000000
# mean    7.066667
# std     2.086236
# min     2.000000
# 25%     6.000000
# 50%     7.000000
# 75%     8.000000
# max    10.000000

# %%
data_test.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>
